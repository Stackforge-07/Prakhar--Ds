# %% [markdown]
# Pandaaa kyu padhuuu

# %%
import pandas as pd
file=pd.read_csv("./student_data.csv",sep=',')
# print(file)

df=pd.DataFrame(file)
# print(df)

print(file.head(8)) #first 8 rows de dega
print(file.tail()) #by default value 5
# Out:
#    study_hours  attendance  sleep_hours  internet_usage  \
# 0            7          56            8               7
# 1            4          69            5               3
# 2           11          60            7               6
# 3            8          99            9               8
# 4            5          52            8               6
# 5            7          40            9              10
# 6           10          40            4              11
# 7            3          86            7               3
#
#    assignments_completed  previous_score  exam_score placement_status
# 0                     10              62      100.00           Placed
# 1                      8              56      100.00           Placed
# 2                     10              45      100.00           Placed
# 3                      4              55       90.17           Placed
# 4                      8              40       78.82           Placed
# ...
