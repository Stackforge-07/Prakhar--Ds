# %% [markdown]
# Pandaaa

# %%
import pandas as pd

dct={
    "name":["brownie","kunafa" ,"horlicks" ,"pohe"],
    "age":[100,20,25,None],
    "roll":[1,2,3,4]
}

# df=pd.DataFrame(dct) #Dataframe--> complete table of data
# print(df) it can also be used but we used display fucn
df1=pd.DataFrame(dct,index=['a','b','c','d'])

# display(df)
# display(df1)

# %%
df=pd.read_csv("./student_data.csv",sep=',')
# df.head()
# df.tail(8) #last se 8


#data about data is meta data
#meta data-->kitne column,row,har column row ka data type
#data.info gives you meta data of the file
#non-null  tells how many non null columns 
# df.info()

#count tells how many column values are here we have 10k which mean fully filled
#std tells how data is differeing,close data std is lesss
#quartile 1st quartile & 25% -->start to median tak ka median
#quartile 2nd quartile & 50% -->median
#quartile 3rd quartile & 75% -->median to end ka median
# df.describe()

# %%
# df.columns
# df.index
# df.sort_index


# df['study_hours'] #-->columns access karne ke liye
# df[['study_hours','internet_usage']] # dataframe me list pass karenege na ki data directly

# df.study_hours. #--.dont use this method use brackets

# df.iloc[0] #-->column ka data row ke form me milega form me data milega but row data hai
# df.iloc[0:8]

# %%
#loc and iloc access data row wise but iloc works on index only but loc works on conditions,index also
# df.loc[df['study_hours']==11]
# df.loc[df['sleep_hours']==7]

# df.loc[df['study_hours']==11,['study_hours','sleep_hours']].iloc[4:8] #iloc se range access kar rahe hai

#df.loc[2] selects row with index labels 2
#df.iloc[2] selects the 3rd row (index position 2)
# df.loc[2]
# df.iloc[2]

#loc humesa row access karta hai iloc indexing pe kaam karta hai
# df.loc[df['assignments_completed']==8].iloc[1]

# %%
# df[df['assignments_completed']>=20]
# df['age']=17 #-->new section add kar sakte hai
# display(df)
# # df=df.rename(columns={'assignments_completed' :'assign_completed'})#yaha ye new data frame return kar raha hai usi data me change karne ke liye inplace =true kardo
# # display(df)

# # df.rename(columns={'assignments_completed': 'assign_completed'}, inplace=True)
# # display(df)

# %%
#df.drop removes row columns
# df.drop({'assignments_completed','sleep_hours'},axis=1)
# df.drop({0,1},axis=0)

#remove missing values df.dropna()
# print(df1)
# df1.dropna(axis=1)

# %%
# df.sort_index(axis=0,ascending=False)
# df.sort_index(axis=1) #indexing ko dekhega 
# df.sort_values()

# %%
# check for missing values
# df1.isnull()


#check for non missing values
# df.notnull()


#replace missing values
# df1.fillna(3) #null ki jagah 3  aa gaya


# df['attendance'].unique()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qn/8dfcn6ms4szbnvhw2588ng0h0000gn/T/ipykernel_91491/3220279162.py in ?()
# ----> 1 df.groupby()
#
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py in ?(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9204
#    9205         from pandas.core.groupby.generic import DataFrameGroupBy
#    9206
#    9207         if level is None and by is None:
# -> 9208             raise TypeError("You have to supply one of 'by' and 'level'")
#    9209
#    9210         return DataFrameGroupBy(
#    9211             obj=self,
#
# TypeError: You have to supply one of 'by' and 'level'
